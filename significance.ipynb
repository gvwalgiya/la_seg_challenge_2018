# %% [markdown]
# # significance.ipynb
# Test to see if there are significant differences in intensity values between samples and within samples for each method of standardising.
#
# There shouldn't be because the intensity/contrast does not actually mean anything in terms of where the LA is.
#
# <b>A work in progress - just started</b>

# %%
import numpy as np
import pandas as pd

# %%
samples = ["sample_1", "sample_2", "sample_3"]
methods = ["lgemri", "rescl", "std", "cv_norm"]

# %%
data_df = pd.DataFrame(columns=["Sample", "Method", "Layer", "Intensity"])
data_list = [data_df]

# %%
for sample in samples:
    for method in methods:
        for layer in range(88):
            current = np.load(sample+"/"+method+"/layer_"+str(layer+1)+".npy")
            current = current.flatten()
            current_df = pd.DataFrame(data=current, columns=["Intensity"])
            current_df["Sample"] = sample
            current_df["Method"] = method
            current_df["Layer"] = layer+1
            print(sample)
            print(method)
            print(layer+1)
            print("-------")
            data_list.append(current_df)
# Out:
# sample_1
# lgemri
# 1
# -------
# sample_1
# lgemri
# 2
# -------
# sample_1
# lgemri
# 3
# -------
# sample_1
# lgemri
# 4
# -------
# sample_1
# lgemri
# 5
# -------
# sample_1
# lgemri
# 6
# -------
# sample_1
# lgemri
# 7
# -------
# sample_1
# lgemri
# 8
# -------
# sample_1
# lgemri
# 9
# -------
# sample_1
# lgemri
# 10
# -------
# sample_1
# lgemri
# 11
# -------
# sample_1
# lgemri
# 12
# -------
# sample_1
# lgemri
# 13
# -------
# sample_1
# lgemri
# 14
# -------
# sample_1
# lgemri
# 15
# -------
# sample_1
# lgemri
# 16
# -------
# sample_1
# lgemri
# 17
# -------
# sample_1
# lgemri
# 18
# -------
# sample_1
# lgemri
# 19
# -------
# sample_1
# lgemri
# 20
# -------
# sample_1
# lgemri
# 21
# -------
# sample_1
# lgemri
# 22
# -------
# sample_1
# lgemri
# 23
# -------
# sample_1
# lgemri
# 24
# -------
# sample_1
# lgemri
# 25
# -------
# sample_1
# lgemri
# 26
# -------
# sample_1
# lgemri
# 27
# -------
# sample_1
# lgemri
# 28
# -------
# sample_1
# lgemri
# 29
# ...

# %%
data_df = pd.concat(data_list)

# %%
data_df.head()
# Out:
#   Intensity Layer  Method    Sample
# 0         0     1  lgemri  sample_1
# 1         0     1  lgemri  sample_1
# 2         0     1  lgemri  sample_1
# 3         1     1  lgemri  sample_1
# 4         0     1  lgemri  sample_1
